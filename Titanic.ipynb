# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv("tested.csv")

# %%
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ..                                            ...     ...   ...    ...    ...
# 413                            Spector, Mr. Woolf    male   NaN      0      0
# 414                  Oliva y Ocana, Dona. Fermina  female  39.0      0      0
# 415                  Saether, Mr. Simon Sivertsen    male  38.5      0      0
# 416                           Ware, Mr. Frederick    male   NaN      0      0
# 417                      Peter, Master. Michael J    male   NaN      1      1
#
#                  Ticket      Fare Cabin Embarked
# 0                330911    7.8292   NaN        Q
# 1                363272    7.0000   NaN        S
# 2                240276    9.6875   NaN        Q
# 3                315154    8.6625   NaN        S
# 4               3101298   12.2875   NaN        S
# ..                  ...       ...   ...      ...
# 413           A.5. 3236    8.0500   NaN        S
# 414            PC 17758  108.9000  C105        C
# 415  SOTON/O.Q. 3101262    7.2500   NaN        S
# 416              359309    8.0500   NaN        S
# 417                2668   22.3583   NaN        C
#
# [418 rows x 12 columns]

# %%
data.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
features=["Pclass","SibSp","Parch","Sex"]

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split

# %%
x=pd.get_dummies(data[features])

# %%
y=data["Survived"]

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
x_train
# Out:
#      Pclass  SibSp  Parch  Sex_female  Sex_male
# 336       2      0      0       False      True
# 31        2      2      0       False      True
# 84        2      0      0       False      True
# 287       1      1      0       False      True
# 317       2      0      0       False      True
# ..      ...    ...    ...         ...       ...
# 71        3      0      0       False      True
# 106       3      0      0       False      True
# 270       1      0      0       False      True
# 348       2      0      0       False      True
# 102       3      0      0       False      True
#
# [334 rows x 5 columns]

# %%
x_test
# Out:
#      Pclass  SibSp  Parch  Sex_female  Sex_male
# 321       3      0      0       False      True
# 324       1      0      0        True     False
# 388       3      0      0       False      True
# 56        3      0      0       False      True
# 153       3      0      2        True     False
# ..      ...    ...    ...         ...       ...
# 57        3      0      0       False      True
# 126       3      0      0       False      True
# 24        1      1      3        True     False
# 17        3      0      0       False      True
# 66        3      0      0        True     False
#
# [84 rows x 5 columns]

# %%
model=RandomForestClassifier(n_estimators=100,max_depth=10,random_state=1)

# %%
model.fit(x,y)
# Out:
# RandomForestClassifier(max_depth=10, random_state=1)

# %%
prediction=model.predict(x_test)

# %%
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report

# %%
accuracy_score(y_test,prediction)
# Out:
# 1.0

# %%
confusion_matrix(y_test,prediction)
# Out:
# array([[50,  0],
#        [ 0, 34]])

# %%
print(f"classification_report is :\n{classification_report(y_test,prediction)}")
# Out:
# classification_report is :
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        50
#            1       1.00      1.00      1.00        34
#
#     accuracy                           1.00        84
#    macro avg       1.00      1.00      1.00        84
# weighted avg       1.00      1.00      1.00        84
